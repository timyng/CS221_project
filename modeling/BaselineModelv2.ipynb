# %%
import sklearn
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import OneHotEncoder

# %%
# Helper functions
def convert_si_to_number(x):
    total_stars = 0
    if 'k' in x:
        if len(x) > 1:
            total_stars = float(x.replace('k', '')) * 1000 # convert k to a thousand
    elif 'M' in x:
        if len(x) > 1:
            total_stars = float(x.replace('M', '')) * 1000000 # convert M to a million
    elif 'B' in x:
        total_stars = float(x.replace('B', '')) * 1000000000 # convert B to a Billion
    else:
        total_stars = int(x) # Less than 1000
    
    return int(total_stars)

# %%
import pandas as pd
X = pd.read_csv("../data/30000-40000.csv")

# %%
X
# Out:
#                                           Name                 Location  \
# 0                           Seven-Eleven Japan             Tokyo, Japan
# 1                        AXIS Capital Holdings        Hamilton, Bermuda
# 2                                   Q Analysts             San Jose, CA
# 3                                 KeytronicEMS       Spokane Valley, WA
# 4                 Independent Project Analysis              Ashburn, VA
# 5                                     INTECSEA              Houston, TX
# 6                              Digital Turbine               Austin, TX
# 7                        Sapphire Technologies               Woburn, MA
# 8                          Parkson Corporation      Fort Lauderdale, FL
# 9                              envision pharma  Horsham, United Kingdom
# 10                               Planet Energy          Toronto, Canada
# 11                                   Trilliant         Redwood City, CA
# 12                                      Merlin             New York, NY
# 13                                         JIM            Paris, France
# 14                            Ingenia Polymers              Houston, TX
# 15                                   Taco Time           Scottsdale, AZ
# 16                          Astir It Solutions     South Plainfield, NJ
# 17                       Antenna International   London, United Kingdom
# 18                     Gold Coast IT Solutions              Milford, CT
# 19         Castleton Commodities International             Stamford, CT
# 20                                    Datorama             New York, NY
# 21                                      Yogibo               Nashua, NH
# 22                                 Lee Kum Kee        Tai Po, Hong Kong
# 23                                        GDKN          Cooper City, FL
# 24                 Concept Software & Services           Alpharetta, GA
# 25                                    SurePrep               Irvine, CA
# 26                               Bossard Group         Zug, Switzerland
# 27                                        LISA              Nogales, AZ
# 28               Project Concern International            San Diego, CA
# 29                                    Innovyze             Portland, OR
# ...                                        ...                      ...
# 12024                          Shieff Services           San Marcos, TX
# 12025                                   Kendal       Kennett Square, PA
# 12026                         Boston Barricade           Vero Beach, FL
# 12027                               LeadCrunch            San Diego, CA
# 12028                         Betenbough Homes              Lubbock, TX
# 12029                       The Lukens Company            Arlington, VA
# 12030                             NTT Training           Centennial, CO
# 12031                       O'Brien Auto Group             Bellevue, WA
# 12032                            Recovery Ways               Murray, UT
# 12033  Satellite Affordable Housing Associates             Berkeley, CA
# 12034                  Larson Automotive Group               Tacoma, WA
# 12035           Kensington Management Services          Upper Darby, PA
# 12036           Keystone Behavioral Pediatrics         Jacksonville, FL
# 12037                            Clarus Agency               Austin, TX
# 12038                     AMT Senior Aerospace            Arlington, WA
# 12039                 Daniels Moving & Storage              Wichita, KS
# 12040                             Technologent               Irvine, CA
# 12041                               HireBetter               Austin, TX
# 12042                          Choice Homecare            Grapevine, TX
# 12043                          Summer Classics               Pelham, AL
# 12044                          Upward Projects              Phoenix, AZ
# 12045                           Wolf Furniture             Bellwood, PA
# 12046          Paladar Latin Kitchen & Rum Bar            Beachwood, OH
# 12047                  Trimark Associates Inc.               Folsom, CA
# 12048                      The Keri Shull Team            Arlington, VA
# 12049                            Decision Lens            Arlington, VA
# 12050      Consolidated Asset Recovery Systems              Raleigh, NC
# 12051                         Atherton Regency           Menlo Park, CA
# 12052                        A Brighter Avenue              Gilbert, AZ
# 12053                         1st Alliance Len                      NaN
#
#        Score reviews salaries interviews
# 0        3.2      46       21         10
# 1        2.5      46       39          9
# 2        4.0      45       42         15
# 3        3.2      45      107          3
# 4        3.5      45       88         18
# 5        3.7      45      135          9
# 6        3.5      45       28         15
# 7        2.9      44      877         17
# 8        3.0      44       55          5
# 9        3.6      44       40         27
# 10       3.7      44       33         14
# 11       3.0      43       45          7
# 12       4.1      43       15          6
# 13       4.0      42       18          5
# 14       3.9      41       27         13
# 15       3.3      41       32          4
# 16       3.7      41     1.3k          6
# 17       2.6      41       33          4
# 18       4.2      41       35         31
# 19       3.4      41       69         10
# 20       4.5      41       14         21
# 21       3.0      41       22          8
# 22       2.1      40       31          9
# 23       3.3      40       23          7
# 24       4.1      40      213          4
# 25       2.9      40       35          6
# 26       3.5      40       37          3
# 27       3.5      40       19         14
# 28       2.8      40       12          8
# 29       4.1      40       12          4
# ...      ...     ...      ...        ...
# 12024    1.9      20       17         --
# 12025    3.9      20       15          2
# 12026    2.6      20       12          2
# 12027    3.9      20       10          7
# 12028    4.4      20        3          2
# 12029    2.6      20       20          3
# 12030    3.3      20       12          2
# 12031    3.2      20        8          3
# 12032    3.4      20        8          2
# 12033    3.3      20       10         --
# 12034    2.4      20       21          6
# 12035    4.4      20        8          7
# 12036    3.1      20       10          1
# 12037    3.8      20       --         --
# 12038    3.5      20       11          1
# 12039    2.9      20        8          1
# 12040    3.5      20       12          1
# 12041    3.8      20        4          1
# 12042    3.5      20       11          1
# 12043    3.1      20        9         --
# 12044    4.2      20       14          6
# 12045    3.2      20       13          6
# 12046    3.3      20        7         --
# 12047    4.0      20       10          6
# 12048    4.7      20        8          3
# 12049    4.1      20        6          1
# 12050    3.3      20        6         --
# 12051    2.7      20       17          5
# 12052    3.2      20       --          2
# 12053    NaN     NaN      NaN        NaN
#
# [12054 rows x 6 columns]
